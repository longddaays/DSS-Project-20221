# %% [markdown]
# # Topsis model demo

# %%
topsis = pd.read_csv('data/result.csv')

# %%
topsis.sort_values(by=['rank'])
# Out:
#                                                   name  avgpoint  avg_price  \
# 267                       Bánh Tráng Cô Bông - Hàng Bè       9.8    25000.0
# 170                Nắng Juice - Nước Ép & Trà Trái Cây       9.8    27500.0
# 402             Ngọc Diệp - Bánh Mì Sốt Vang & Tào Phớ       9.8    29000.0
# 214           Trà Sữa Nướng Yi He Kao Nai - Trung Kiên       9.9    32500.0
# 274  Sữa Chua Trân Châu Cô Thỏ - KTT Trường Múa Việ...       9.6    30000.0
# ..                                                 ...       ...        ...
# 41   Sumo BBQ - Nhà Hàng Thịt Nướng Nhật Bản - Tô H...       7.6   375000.0
# 203            GoGi House - Nướng Hàn Quốc - Trung Hòa       7.7   399500.0
# 39            GoGi House - Nướng Hàn Quốc - Royal City       8.1   425000.0
# 244                        Lotteria - Huỳnh Thúc Kháng       6.8   465000.0
# 180                       Lẩu Đức Trọc - Dịch Vọng Hậu       4.2   797500.0
#
#      num_reviews  topsis_score  rank
# 267           26      0.977623     1
# 170           30      0.974877     2
# 402           11      0.973210     3
# 214           20      0.970222     4
# 274           15      0.968349     5
# ..           ...           ...   ...
# 41           107      0.557608   437
# 203           85      0.532377   438
# 39           175      0.510910   439
# 244           75      0.447954   440
# 180           12      0.104318   441
#
# [441 rows x 6 columns]

# %% [markdown]
# # Calculate Distance

# %%
import googlemaps
gmaps = googlemaps.Client(key='AIzaSyD6HqlWEEDsiS41-aoBRdZmUunsMYL-VkI')

def calDist(data, userloc):
    dis_matrix = []
    time_matrix = []
    # userloc = input()
    for i in range(data.shape[0]):
    # for i in range(n):
        # data = pd.read_csv('data/dss_data_test.csv')
        my_dist = gmaps.distance_matrix(userloc,data['location'].iloc[i])['rows'][0]['elements'][0]
        distance = my_dist['distance']['text']
        time  = my_dist['duration']['text']
        dis_matrix.append(distance)
        time_matrix.append(time)
        
    return dis_matrix, time_matrix

# %% [markdown]
# # Return True if restaurants are opening

# %%
def timeDataFrame(data):
    x = []
    for i in range(data.shape[0]):
        # if (data['start_time2'].iloc[i] != None  and data['end_time2'].iloc[i]!= None): 
        try:
            try:
                x.append((data['start_time1'].iloc[i] <= current <= data['end_time1'].iloc[i]) 
                or (data['start_time2'].iloc[i] <= current <= data['end_time2'].iloc[i])
                or (data['end_time1'].iloc[i] <= current <= data['start_time1'].iloc[i]) 
                or (data['end_time2'].iloc[i] <= current <= data['start_time2'].iloc[i]))
            except: x.append((data['start_time1'].iloc[i] <= current <= data['end_time1'].iloc[i]) 
                or (data['end_time1'].iloc[i] <= current <= data['start_time1'].iloc[i]))
        except: x.append(True)        
    return x

# %% [markdown]
# # Time transformation

# %%
from datetime import datetime
def timeTransform(data):
    data['time_open'].head(2)
    data_new = data.copy()
    data_new[['time1','time2']] = data_new['time_open'].str.split('|',1, expand = True)
    data_new[["start_time1","end_time1"]] = data_new["time1"].str.split('-', 1, expand=True)
    data_new[["start_time2","end_time2"]] = data_new["time2"].str.split('-', 1, expand=True)
    data_new["start_time1"] = data_new["start_time1"].str.split().str.join(' ')
    data_new["start_time2"] = data_new["start_time1"].str.split().str.join(' ')
    data_new["end_time1"] = data_new["end_time1"].str.split().str.join(' ')
    data_new["end_time2"] = data_new["end_time2"].str.split().str.join(' ')
    for i in range(data_new.shape[0]):
        try:
            try: 
                data_new["start_time2"].iloc[i] = datetime.strptime(data_new["start_time2"].iloc[i], '%H:%M').time()
                data_new["end_time2"].iloc[i] = datetime.strptime(data_new["end_time2"].iloc[i], '%H:%M').time()
            finally: 
                data_new["start_time1"].iloc[i] = datetime.strptime(data_new["start_time1"].iloc[i], '%H:%M').time()
                data_new["end_time1"].iloc[i] = datetime.strptime(data_new["end_time1"].iloc[i], '%H:%M').time()
        except: continue
    return data_new

# %%
from datetime import datetime
# import time_transform

data = pd.read_csv('../data/dss_data_prep.csv')
data_new = timeTransform(data)
# timeDataFrame(data)
# Out:
# c:\Users\hlong\pyver\py37\my_env\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
current = datetime.datetime.now().time()
type(current)
# Out:
# datetime.time

# %%
timeDataFrame(data_new)
# Out:
# [True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]

# %% [markdown]
# # Input data

# %%
import pandas as pd
import datetime
data = pd.read_csv('../data/dss_data_prep.csv')

def newData(n):
    data['name'] = data['name'] + '; ' + data['cuisines']

    print('Nhập vào món bạn muốn ăn:')
    queries = input()


    # Select a list of restaurants, in which each restaurant's menu includes user's input dish
    data_querry = data[data['cuisines'].str.contains(queries)]
    if (data_querry.shape[0] != 0 and len(queries) != 0): 
        print(queries)
    else: print('Món ăn không tồn tại, vui lòng nhập lại')

    print('Nhập vào giá tiền phù hợp với bạn:')
    prices = input()
    try: 
        if (int(prices) >= 0): 
            print(prices)
        else: print('Vui lòng nhập vào số tự nhiên >= 0')
    except: print('Không phải là 1 số, vui lòng nhập lại')
    
    # Differences between user' expected price and restaurant's average price
    data_querry['avg_price'] = abs(data_querry['avg_price'] - int(prices))

    data_querry = data_querry[timeDataFrame(data_querry)]
    current = datetime.datetime.now().time()

    data_new = data_querry[['name','avgpoint','avg_price','num_reviews']].copy()
    data_new_10 = data_new.head(n)

    # Calculate the distance between the user's location and the destination restaurants

    # try:
    #     print('Nhập vào vị trí của bạn:')
    #     user_loc = input()
    #     print(user_loc)
    #     data_new_10['distance'], data_new_10['time_to_restaurant'] = calDist(data_querry.head(n), user_loc) 
    # except: print('Đã xảy ra lỗi! Hãy nhập lại')

    # # Convert hours to minutes
    # data_new_10[['time_to_restaurant_hours'],['time_to_restaurant_minutes']] = data_new_10['time_to_restaurant'].str.split('h', expand=True)
    # data_new_10['time_to_restaurant_minutes'] = data_new_10['time_to_restaurant_minutes'].str.replace('m','')
    # data_new_10['weight'] = 60
    # data_new_10['time_to_restaurant'] = (data_new_10['time_to_restaurant_hours'].astype(int))*data_new_10['weight'] + data_new_10['time_to_restaurant_minutes'].astype(int)

    # Convert all measurement into a unique unit, which is km
    # data_new_10["Weight"] = 1e-3
    # data_new_10.loc[data_new_10["distance"].str.contains("km"),"Weight"] = 1
    # data_new_10['distance'] = data_new_10['distance'].str.replace("km","")
    # data_new_10['distance'] = data_new_10['distance'].str.replace("m","")
    # data_new_10['distance'] = data_new_10['distance'].astype(float)
    # data_new_10['distance'] = data_new_10['distance'] * data_new_10["Weight"]
    # data_new_10 = data_new_10.drop("Weight",axis=1)
    # data_new_10.to_csv('data/new_dis.csv',index=False)

    return data_new_10

# %%
newData(3)
# Out:
# Nhập vào món bạn muốn ăn:
# cháo
# Nhập vào giá tiền phù hợp với bạn:
# 100000
# c:\Users\hlong\pyver\py37\my_env\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                  name  avgpoint  avg_price  \
# 3   Phở Gà 95 - Doãn Kế Thiện; thịt gà phở món nướ...       7.0    62500.0
# 13  Pane e Vino - Ẩm Thực Ý - Nguyễn Khắc Cần; mì ...       7.8    62500.0
# 18  Gà 36 - Hà Đông; thịt gà lẩu thức uống cháo gà...       6.2    35000.0
#
#     num_reviews
# 3             1
# 13           39
# 18           22

# %% [markdown]
# # Topsis Model

# %%
import pandas as pd
from topsis import Normalize, Calc_Values

def topsis_pipy(temp_dataset, dataset, nCol, weights, impact):
    
    temp_dataset = Normalize(temp_dataset, nCol, weights)

    
    p_sln, n_sln = Calc_Values(temp_dataset, nCol, impact)

    
    
    score = []
    for i in range(len(temp_dataset)):
        temp_p, temp_n = 0, 0
        for j in range(1, nCol):
            temp_p = temp_p + (p_sln[j-1] - temp_dataset.iloc[i, j])**2
            temp_n = temp_n + (n_sln[j-1] - temp_dataset.iloc[i, j])**2
        temp_p, temp_n = temp_p**0.5, temp_n**0.5
        score.append(temp_n/(temp_p + temp_n))
    dataset['topsis_score'] = score

    
    dataset['rank'] = (dataset['topsis_score'].rank(
        method='max', ascending=False))
    dataset = dataset.astype({"rank": int})

# %% [markdown]
# # Topsis Ranking

# %%
data = pd.read_csv('../data/dss_data_prep.csv')
# dataa = newData(data.shape[0])
data.head(2)
# Out:
#                                 name           price  avgpoint  category  \
# 0                       Sushi Garden  50000 - 150000       7.2   Quán ăn
# 1  Cuốn N Roll Restaurant - Giảng Võ  40000 - 468000       7.1  Nhà hàng
#
#                                             location  num_reviews  \
# 0  310 Nguyễn Trãi, P. Thanh Xuân Trung, Quận Tha...           67
# 1  Tầng 3 Tòa Nhà D2, Giảng Võ, P. Giảng Võ, Quận...           64
#
#                                      dish_categories  \
# 0  Lẩu, Sushi & Sashimi, Salad, Ăn vặt - Ăn nhẹ, ...
# 1       Heo quay, Bún, Lẩu, Món Huế, Ăn vặt - Ăn nhẹ
#
#                         time_open  dieu_hoa  bong_da  wifi  \
# 0                   10:00 - 22:00         1        0     1
# 1   17:00 - 21:30 | 09:00 - 13:30         1        0     1
#
#                                             cuisines  min_price  max_price  \
# 0  lẩu sushi sashimi salad ăn vặt ăn nhẹ cơm nem ...      50000     150000
# 1  heo quay bún lẩu món huế ăn vặt ăn nhẹ giỏ quà...      40000     468000
#
#    avg_price                                               menu
# 0   100000.0  Set Cá Hồi, Lươn-159,000|Set Nigiri Tổng Hợp-1...
# 1   254000.0  Giỏ Quà Tết Yêu Thương-458,000|Cốt Lẩu Chua Ca...

# %%
def topsis_ranking(weights,n):    
    dataa = newData(n)
    dat = dataa.copy()
    temp = dataa.copy()
    # weights = [10,5,1,2]
    impact = ["+","-","+","-"]
    topsis_pipy(dat,temp,4,weights,impact)
    temp[["name","dishes"]] = temp["name"].str.split(';', 1, expand=True)
    return temp.sort_values(by=['rank'])

# %%
weight = [10,5,1,2]
topsis_ranking(weight)
# Out:
# Nhập vào món bạn muốn ăn:
# cháo
# Nhập vào giá tiền phù hợp với bạn:
# c:\Users\hlong\pyver\py37\my_env\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100000
# Nhập vào vị trí của bạn:
# hà nội
# Đã xảy ra lỗi! Hãy nhập lại
# c:\Users\hlong\pyver\py37\my_env\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\hlong\pyver\py37\my_env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'distance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10824\1786192043.py in <module>
#       1 weight = [10,5,1,2]
# ----> 2 topsis_ranking(weight)
#
# ~\AppData\Local\Temp\ipykernel_10824\3157362693.py in topsis_ranking(weights)
#       1 def topsis_ranking(weights):
# ----> 2     dataa = newData(10)
#       3     dat = dataa.copy()
#       4     temp = dataa.copy()
#       5     # weights = [10,5,1,2]
#
# ~\AppData\Local\Temp\ipykernel_10824\374750496.py in newData(n)
#      44     # Convert all measurement into a unique unit, which is km
#      45     data_new_10["Weight"] = 1e-3
# ---> 46     data_new_10.loc[data_new_10["distance"].str.contains("km"),"Weight"] = 1
#      47     data_new_10['distance'] = data_new_10['distance'].str.replace("km","")
#      48     data_new_10['distance'] = data_new_10['distance'].str.replace("m","")
#
# c:\Users\hlong\pyver\py37\my_env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# c:\Users\hlong\pyver\py37\my_env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'distance'

# %%
topsis_ranking
# Out:
#                                    name  avgpoint  avg_price  num_reviews  \
# 0                          Sushi Garden       7.2   100000.0           67
# 1     Cuốn N Roll Restaurant - Giảng Võ       7.1   254000.0           64
# 2                       Mì Gia Tiến Đạt       7.6    37500.0           18
# 3             Phở Gà 95 - Doãn Kế Thiện       7.0    37500.0            1
# 4         Bánh Cuốn Phủ Lý - Đào Duy Từ       7.0    42500.0            9
# 5          Glamour - Cơm Niêu Singapore       3.0    75000.0            1
# 6               Bún Riêu Cua - Giảng Võ       6.8    35000.0            3
# 7  Anh Hòa French Bakery - Trường Chinh       7.3   325000.0            6
# 8         Vịt Hầm Hồng Kông - 92 Hòa Mã       6.8   272500.0            2
# 9                 Vó & Xách Bò - Hòa Mã       6.3    60000.0            3
#
#    distance  topsis_score  rank  \
# 0     0.001      0.817679   6.0
# 1     5.800      0.490730   8.0
# 2     6.400      0.993193   1.0
# 3     7.300      0.922022   2.0
# 4     8.500      0.919091   3.0
# 5     6.800      0.522958   7.0
# 6     5.700      0.898127   4.0
# 7     3.600      0.419542  10.0
# 8     7.500      0.444708   9.0
# 9     7.500      0.819729   5.0
#
#                                               dishes
# 0  Lẩu, Sushi & Sashimi, Salad, Ăn vặt - Ăn nhẹ, ...
# 1       Heo quay, Bún, Lẩu, Món Huế, Ăn vặt - Ăn nhẹ
# 2        Bún, Hủ tiếu, Mì, Món nước, Sủi cảo, Dimsum
# 3                 Thịt Gà, Phở, Món nước, Cháo, Miến
# 4  Bánh ướt, Bún, Bánh - Kẹo, Bánh cuốn, Ăn vặt -...
# 5                                                Cơm
# 6                                      Bún, Món nước
# 7                                         Bánh - Kẹo
# 8  Vịt tiềm, Lẩu, Thịt Vịt, Ăn vặt - Ăn nhẹ, Nem,...
# 9                                            Thịt Bò

# %% [markdown]
# # RecomSys based on users' interaction history

# %%
import text_prep

# %%
temp = topsis_ranking()

# %%
temp['cuisines'] = temp['cuisines'].apply(text_prosessing)

# %%
temp['cuisines']
# Out:
# 0        lẩu sushi sashimi salad ăn vặt ăn nhẹ cơm nem
# 1               heo quay bún lẩu món huế ăn vặt ăn nhẹ
# 2               bún hủ tiếu mì món nước sủi cảo dimsum
# 3                       thịt gà phở món nước cháo miến
# 4        bánh ướt bún bánh kẹo bánh cuốn ăn vặt ăn nhẹ
# 5                                                  cơm
# 6                                         bún món nước
# 7                                             bánh kẹo
# 8    vịt tiềm lẩu thịt vịt ăn vặt ăn nhẹ nem cá bò ...
# 9                                              thịt bò
# Name: dishes, dtype: object

# %% [markdown]
# # Tf - Idf Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

#Vec-tơ hóa từ
vectorizer = TfidfVectorizer(analyzer = 'word', ngram_range = (1,2), min_df = 0)
vectorizer.fit(temp['cuisines'])
x_train_tfidf = vectorizer.transform(temp['cuisines'])

#Độ tương đồng cosine
cosine_sim = cosine_similarity(x_train_tfidf, x_train_tfidf)
cosine_sim.shape

# %% [markdown]
# # Restaurant Recommendations based on Users' past experience

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def dish_recommendations(dish, n):

    #Vec-tơ hóa từ
    vectorizer = TfidfVectorizer(analyzer = 'word', ngram_range = (1,2), min_df = 0)
    vectorizer.fit(temp['cuisines'])
    x_train_tfidf = vectorizer.transform(temp['cuisines'])

    #Độ tương đồng cosine
    cosine_sim = cosine_similarity(x_train_tfidf, x_train_tfidf)

    weights = input([])
    temp = topsis_ranking(weights)
    dishes = temp['cuisines']
    indices = pd.Series(temp.index, index = temp['cuisines']) 
    idx = indices[dish]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key = lambda x:x[1], reverse = True)
    sim_scores = sim_scores[1:n+1]
    dish_indices = [i[0] for i in sim_scores]
    
    return temp['name'].iloc[dish_indices]

def restaurant_recom(n):
    result = pd.DataFrame()
    for i in temp['cuisines']:
        output = pd.DataFrame(dish_recommendations(i,n))
        result = result.append(output)
    
    return result['name'].value_counts()

# %% [markdown]
# # Samples

# %%
dish_recommendations('cơm',5)

# %%
result = pd.DataFrame()
n = 3
for i in temp['cuisines']:
    output = pd.DataFrame(dish_recommendations(i,n))
    result = result.append(output)
# result = result.drop_duplicates()

# %%
result['name'].value_counts()
# Out:
# Cuốn N Roll Restaurant - Giảng Võ       3
# Bún Riêu Cua - Giảng Võ                 2
# Vịt Hầm Hồng Kông - 92 Hòa Mã           2
# Sushi Garden                            2
# Bánh Cuốn Phủ Lý - Đào Duy Từ           2
# Anh Hòa French Bakery - Trường Chinh    1
# Vó & Xách Bò - Hòa Mã                   1
# Mì Gia Tiến Đạt                         1
# Phở Gà 95 - Doãn Kế Thiện               1
# Name: name, dtype: int64
